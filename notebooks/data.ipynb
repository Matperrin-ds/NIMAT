# %%
import os
from PIL import Image

import torch
import torchvision.transforms as T
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import functional as F
import gin
torch.multiprocessing.set_sharing_strategy('file_system')

from datasets import load_dataset
# Out:
# /data/nils/miniconda3/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/data/nils/miniconda3/lib/python3.9/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
hubble_dataset = load_dataset(
        "Supermaxman/esa-hubble",
        split="train",
        cache_dir="./data/hubble",
        streaming=False,
       # features = "image",
        num_proc = 16,
    )
# Out:
# ...
# Loading dataset shards:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
len(hubble_dataset)
# Out:
# 2706

# %%
hubble_dataset = load_dataset(
        "Supermaxman/esa-hubble",
        split="train",
        cache_dir="./data/hubble",
        streaming=False,
       # features = "image",
        num_proc = 16,
    )

hubble_dataset.shuffle(seed=42)
hubble_transform = T.Compose([
    T.Resize(1024),
    T.ToTensor(),
    T.RandomCrop(size = 128),
    # T.Normalize(mean = (0,0,0), std = (1,1,1), inplace=False),
])
def collate(batch):
    # batch is a list of samples
    #images = [hubble_transform(sample["image"]) for sample in batch]
    #images = torch.stack(images)
    return batch
hubble_dataloader = DataLoader(hubble_dataset, batch_size=1, num_workers=0, collate_fn=collate)
# Out:
# ...
# Loading dataset shards:   0%|          | 0/79 [00:00<?, ?it/s]

# %%
import os
from PIL import Image

import torch
import torchvision.transforms as T
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import functional as F
import gin
torch.multiprocessing.set_sharing_strategy('file_system')

from datasets import load_dataset



hubble_dataset = load_dataset(
        "Supermaxman/esa-hubble",
        split="train",
        cache_dir="./data/hubble",
        streaming=False,
       # features = "image",
        num_proc = 16,
    )

hubble_dataset.shuffle(seed=42)
hubble_transform = T.Compose([
    T.Resize(1024),
    T.ToTensor(),
    T.RandomCrop(size = 128),
    # T.Normalize(mean = (0,0,0), std = (1,1,1), inplace=False),
])
def collate(batch):
    # batch is a list of samples
    #images = [hubble_transform(sample["image"]) for sample in batch]
    #images = torch.stack(images)
    return batch
hubble_dataloader = DataLoader(hubble_dataset, batch_size=1, num_workers=0, collate_fn=collate)



def crop(im,height,width):
    #im = Image.open(infile)
    print(im.size)
    imgwidth, imgheight = im.size

    for i in range(imgheight//height):
        for j in range(imgwidth//width):
            box = (j*width, i*height, (j+1)*width, (i+1)*height)
            yield im.crop(box)
            

idx = 0


for image in hubble_dataloader:
    image = image[0]["image"]
    
   
    if False:
        H, W = image.size[0], image.size[1]
        print(W, H)
        H = min(2048, H//512 * 512)
        W = min(2048, W//512 * 512)
        
        H, W = H // 2, W // 2 

        H, W = max(H, 512), max(W, 512)
    else:
        H, W = 512, 512

    image = image.resize((H, W))
    
    
    all_images= crop(image, height= 512, width = 512)
    
    
    for j, small_image in enumerate(all_images):
        small_image.save("./data/hubble_processed/" + str(idx)+ "_" + str(j)+ ".png")
        
        
        
    #break
    idx+=1
# Out:
# (512, 512)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 28
#      22 all_images= crop(image, height= 512, width = 512)
#      27 for j, small_image in enumerate(all_images):
# ---> 28     small_image.save("./data/hubble_processed/" + str(idx)+ "_" + str(j)+ ".png")
#      32 #break
#      33 idx+=1
#
# File ~/.local/lib/python3.9/site-packages/PIL/Image.py:2436, in Image.save(self, fp, format, **params)
#    2434         fp = builtins.open(filename, "r+b")
#    2435     else:
# -> 2436         fp = builtins.open(filename, "w+b")
#    2438 try:
#    2439     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/hubble_processed/0_0.png'
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
all_images
# Out:
# <generator object crop at 0x7f12106640b0>

# %%
pip install pinscrape
# Out:
# WARNING: Ignoring invalid distribution -umpy (/net/homes/u.anasynth/demerle/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rpcio (/net/homes/u.anasynth/demerle/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/net/homes/u.anasynth/demerle/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -orch (/net/homes/u.anasynth/demerle/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/net/homes/u.anasynth/demerle/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/net/homes/u.anasynth/demerle/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rpcio (/net/homes/u.anasynth/demerle/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/net/homes/u.anasynth/demerle/.local/lib/python3.9/site-packages)
# ...

# %%
from pinscrape import scraper, Pinterest


search_queries = [
    "Deep space telescope images",
    "NASA deep space photos",
    "Hubble Space Telescope images",
    "James Webb Space Telescope images",
    "Galaxies captured by telescope",
    "Nebulae real telescope images",
    "Cosmos deep space photos",
    "Astronomy real telescope images",
    "Black hole real images",
    "Exoplanets real telescope images",
    "NASA Hubble deep space",
    "Infrared space telescope images",
    "JWST vs Hubble comparison images",
    "Distant universe telescope images",
    "ESA deep space photos",
    "Interstellar space real images",
    "Clusters of galaxies telescope images",
    "Astrophotography deep space",
    "Hubble Ultra Deep Field",
    "NASA space photography"
]
output_folder = "output"
proxies = {}
number_of_workers = 10
images_to_download = 1000

def using_search_engine(keyword):
    details = scraper.scrape(keyword, output_folder, proxies, number_of_workers, images_to_download)
    print(details)
    if details["isDownloaded"]:
        print("\nDownloading completed !!")
        print(f"\nTotal urls found: {len(details['extracted_urls'])}")
        print(f"\nTotal images downloaded (including duplicate images): {len(details['urls_list'])}")
        print(details)
    else:
        print("\nNothing to download !!", details)


for keyword in search_queries:
    using_search_engine(keyword)
# Out:
# {'isDownloaded': True, 'search_engine_status_code': 200, 'urls_list': ['https://i.pinimg.com/originals/1b/54/5d/1b545d5540139deeae4894b5d25633ee.jpg', 'https://i.pinimg.com/originals/26/eb/ba/26ebbab0dce88b39e4c5fde88c610c88.jpg', 'https://i.pinimg.com/originals/ae/c4/38/aec4385dc897644a7c69e59f51d7674b.png', 'https://i.pinimg.com/originals/7f/ee/a7/7feea7317cfd49e1351ed98055109e03.jpg', 'https://i.pinimg.com/originals/bf/86/e2/bf86e28ba3ea055dcf4bc4173d208b01.jpg', 'https://i.pinimg.com/originals/44/41/6b/44416bd3dc40ebc6c925b8568c1ae2d7.jpg', 'https://i.pinimg.com/originals/af/9a/7a/af9a7a5dd787edd2b91341a9f5e3c5dd.jpg', 'https://i.pinimg.com/originals/4e/9e/0e/4e9e0eb20474fdd95fd1849109d2cd2f.jpg', 'https://i.pinimg.com/originals/1f/db/e2/1fdbe2006b0bc68e6b7c16c539c3432b.jpg', 'https://i.pinimg.com/originals/f2/d8/01/f2d801dbfce16649ada02bef2e6222ad.png', 'https://i.pinimg.com/originals/32/fc/ec/32fcecdbcc4f2bd161f419291f4354dc.jpg', 'https://i.pinimg.com/originals/cf/06/8d/cf068d
# ...
